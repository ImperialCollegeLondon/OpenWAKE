# %%
# load modules
import sys
sys.path.append('../')
from imperial_floris.floris import Floris
import numpy as np
import matplotlib.pyplot as plt
from imperial_floris.visualization_manager import VisualizationManager
import imperial_floris.optimisation_manager as optimisation_manager  # MODIFIED modules used for optimizing FLORIS
import imp
import time
import copy

# %% [markdown]
# ## Specify Case Study, Initialise File Names

# %%
# specify case study
case = 'case2'

# specify case file names
init_name = '{}_init'.format(case)
loc_name = '{}_loc'.format(case)
yaw_name = '{}_yaw'.format(case)
loc_yaw_name = '{}_loc_yaw'.format(case)
direction_name = '{}'

# %% [markdown]
# ## No Optimisation

# %%
# start timer
t1 = time.time()
init_floris = Floris('{}.json'.format(case))
num_turbines = len(floris.farm.flow_field.turbine_map.turbine_map)

# determine initial power production
init_floris.farm.flow_field.calculate_wake()

# end timer and print time difference
t2 = time.time()
print('Time to compute wake = ', t2-t1, 's')

# calculate initial power and print
init_power = optimisation_manager.calc_power(init_floris)
print('Initial Power Output = ', init_power/10**6, ' MW')

# plot initial wake_field
ff_viz = init_floris.farm.flow_field
visualization_manager = VisualizationManager(ff_viz, init_name, plot_wakes=True)
visualization_manager.plot_z_planes([0.5])
visualization_manager.plot_x_planes([0.5])
# Out:
# Time to compute wake =  0.023094892501831055 s
# Initial Power Output =  5.102218332510335  MW

# %% [markdown]
# ## Optimise Power Output for Turbine Locations Only with Basin-Hopping

# %%
imp.reload(optimisation_manager)
loc_floris = Floris('{}.json'.format(case))
loc_variables=['layout_x', 'layout_y']

# set bounds for the optimization on the turbine locations
minimum_values = [0.0, 0.0]
maximum_values = [1000.0, 1000.0]

# compute the optimal turbine locations
loc_opt_params, loc_opt_power, loc_data = optimisation_manager.optimise_func(loc_floris, loc_variables, minimum_values, maximum_values, loc_name, case, global_search=True)

# print output at half-way iteration
"""
num_iterations = len(loc_data[1])
iteration = np.int(num_iterations / 2)
loc_subopt_power = loc_data[2][iteration - 1]
loc_subopt_params = loc_data[3][iteration - 1]
optimisation_manager.print_output(loc_floris, loc_data, loc_subopt_params, init_power, loc_subopt_power, loc_variables, num_turbines, is_opt=False, plot_wakes=True)
"""
# Out:
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  8
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5316691.15127381
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 0: f -5.31669e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6839940.742461903
#             Iterations: 25
#             Function evaluations: 286
#             Gradient evaluations: 25
# basinhopping step 1: f -6.83994e+06 trial_f -6.83994e+06 accepted 1  lowest_f -6.83994e+06
# found new global minimum on step 1 with function value -6.83994e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.3964635935
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 2: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 2 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.399085462
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 3: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 3 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.394209681
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 4: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.437896706
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 5: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 5 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.441000953
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 6: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 6 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.466697248
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 7: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 7 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.505685245
#             Iterations: 5
#             Function evaluations: 64
#             Gradient evaluations: 5
# basinhopping step 8: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 8 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.537188144
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 9: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 9 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.550221127
#             Iterations: 6
#             Function evaluations: 82
#             Gradient evaluations: 6
# basinhopping step 10: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 10 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.70000438
#             Iterations: 6
#             Function evaluations: 60
#             Gradient evaluations: 6
# basinhopping step 11: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 11 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.6759810075
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 12: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.656314969
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 13: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.663710142
#             Iterations: 5
#             Function evaluations: 50
#             Gradient evaluations: 5
# basinhopping step 14: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.774498167
#             Iterations: 4
#             Function evaluations: 51
#             Gradient evaluations: 4
# basinhopping step 15: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 15 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.779499469
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 16: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 16 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.8691040175
#             Iterations: 3
#             Function evaluations: 41
#             Gradient evaluations: 3
# basinhopping step 17: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 17 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.843647936
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 18: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.856686517
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 19: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848016.87056856
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 20: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 20 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.293228661
#             Iterations: 5
#             Function evaluations: 61
#             Gradient evaluations: 5
# basinhopping step 21: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 21 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.510496517
#             Iterations: 5
#             Function evaluations: 61
#             Gradient evaluations: 5
# basinhopping step 22: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 22 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.511384093
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 23: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 23 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.565172985
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 24: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 24 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.59938357
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 25: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 25 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.607061911
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 26: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 26 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.993542625
#             Iterations: 13
#             Function evaluations: 140
#             Gradient evaluations: 13
# basinhopping step 27: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 27 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.01165011
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 28: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 28 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848017.997350854
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 29: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.031086245
#             Iterations: 3
#             Function evaluations: 41
#             Gradient evaluations: 3
# basinhopping step 30: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 30 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.03087277
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 31: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.0149598755
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 32: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.026153795
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 33: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.030233431
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 34: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.236513102
#             Iterations: 6
#             Function evaluations: 73
#             Gradient evaluations: 6
# basinhopping step 35: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 35 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.184460688
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 36: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.210705547
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 37: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.361556703
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 38: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 38 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.379292985
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 39: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 39 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.379604872
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 40: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 40 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.391274631
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 41: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 41 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.396576475
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 42: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 42 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.40016283
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 43: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 43 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.394008475
#             Iterations: 4
#             Function evaluations: 59
#             Gradient evaluations: 4
# basinhopping step 44: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.402613447
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 45: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 45 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.407560468
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 46: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 46 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.406615324
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 47: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.395513929
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 48: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.392674309
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 49: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# adaptive stepsize: acceptance rate 0.980000 target 0.500000 new stepsize 0.555556 old stepsize 0.5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.403048616
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 50: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.399348017
#             Iterations: 2
#             Function evaluations: 31
#             Gradient evaluations: 2
# basinhopping step 51: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.411602953
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 52: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 52 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.427844769
#             Iterations: 6
#             Function evaluations: 70
#             Gradient evaluations: 6
# basinhopping step 53: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 53 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.450205657
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 54: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 54 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.46255333
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 55: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 55 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.478030786
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 56: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 56 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.472887564
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 57: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.481177755
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 58: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 58 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.476373607
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 59: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.482830061
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 60: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 60 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.479105344
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 61: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.4834844675
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 62: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 62 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.473561747
#             Iterations: 3
#             Function evaluations: 32
#             Gradient evaluations: 3
# basinhopping step 63: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.458473543
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 64: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.474613064
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 65: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.489250602
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 66: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 66 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.475730138
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 67: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.460825404
#             Iterations: 2
#             Function evaluations: 31
#             Gradient evaluations: 2
# basinhopping step 68: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.445432776
#             Iterations: 2
#             Function evaluations: 31
#             Gradient evaluations: 2
# basinhopping step 69: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.458362415
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 70: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.445418838
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 71: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.442416685
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 72: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.434727911
#             Iterations: 5
#             Function evaluations: 70
#             Gradient evaluations: 5
# basinhopping step 73: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.442546152
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 74: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.424651544
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 75: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.427442486
#             Iterations: 3
#             Function evaluations: 41
#             Gradient evaluations: 3
# basinhopping step 76: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.423888692
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 77: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.485953823
#             Iterations: 4
#             Function evaluations: 51
#             Gradient evaluations: 4
# basinhopping step 78: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.493576565
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 79: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 79 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.492913688
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 80: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.477359746
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 81: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.490125587
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 82: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.479773151
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 83: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.479847519
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 84: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.4809781015
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 85: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.485655885
#             Iterations: 3
#             Function evaluations: 41
#             Gradient evaluations: 3
# basinhopping step 86: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.484656221
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 87: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.692746025
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 88: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 88 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.690420021
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 89: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.705618689
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 90: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 90 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.700438459
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 91: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.748067528
#             Iterations: 5
#             Function evaluations: 61
#             Gradient evaluations: 5
# basinhopping step 92: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 92 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.735476287
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 93: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.758304414
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 94: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 94 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.780559561
#             Iterations: 3
#             Function evaluations: 41
#             Gradient evaluations: 3
# basinhopping step 95: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 95 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.792258829
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 96: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 96 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.813769641
#             Iterations: 4
#             Function evaluations: 53
#             Gradient evaluations: 4
# basinhopping step 97: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 97 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.864429411
#             Iterations: 4
#             Function evaluations: 53
#             Gradient evaluations: 4
# basinhopping step 98: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# found new global minimum on step 98 with function value -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.855113556
#             Iterations: 1
#             Function evaluations: 21
#             Gradient evaluations: 1
# basinhopping step 99: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# adaptive stepsize: acceptance rate 0.990000 target 0.500000 new stepsize 0.617284 old stepsize 0.555556
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.8576363595
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 100: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Optimised  Parameters:
# Turbine 0 parameter layout_x = 121.09058988967004
# Turbine 1 parameter layout_x = 997.2255724320488
# Turbine 2 parameter layout_x = 808.1039826289469
# Turbine 3 parameter layout_x = 796.7915029518254
# Turbine 0 parameter layout_y = 500.5793581209697
# Turbine 1 parameter layout_y = 18.97131284835873
# Turbine 2 parameter layout_y = 203.35577152288852
# Turbine 3 parameter layout_y = 801.9034219811774
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 6.84801886442941 MW
# Power increased by 34.216499925045866%
# Time to optimise wake = 28.69648003578186 s
# '\nnum_iterations = len(loc_data[1])\niteration = np.int(num_iterations / 2)\nloc_subopt_power = loc_data[2][iteration - 1]\nloc_subopt_params = loc_data[3][iteration - 1]\noptimisation_manager.print_output(loc_floris, loc_data, loc_subopt_params, init_power, loc_subopt_power, loc_variables, num_turbines, is_opt=False, plot_wakes=True)\n'

# %% [markdown]
# ## Optimise Power Output for Yaw Angle after Turbine Location with Basin-Hopping

# %%
# set variable(s) to optimise for
imp.reload(optimisation_manager)
yaw_variables=['yaw_angle']

# set bounds for the optimization on the turbine parameters (radians for angles)
minimum_values = [-0.5]
maximum_values = [0.5]

# compute the optimal yaw angles
loc_yaw_opt_params, loc_yaw_opt_power, loc_yaw_data = optimisation_manager.optimise_func(loc_floris, yaw_variables, minimum_values, maximum_values, loc_yaw_name, case, global_search=True)

# print output at halfway iteration
"""
num_iterations = len(loc_data[1])
iteration = np.int(num_iterations / 2)
loc_yaw_subopt_power = loc_yaw_data[2][iteration - 1]
loc_yaw_subopt_params = loc_yaw_data[3][iteration - 1]
optimisation_manager.print_output(floris, loc_yaw_data, loc_yaw_subopt_params, init_power, loc_yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)
"""
# Out:
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.857636379
#             Iterations: 1
#             Function evaluations: 14
#             Gradient evaluations: 1
# basinhopping step 0: f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6473612.678850304
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -6.84802e+06 trial_f -6.47361e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5786843.189258426
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -6.84802e+06 trial_f -5.78684e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6745781.752921386
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -6.84802e+06 trial_f -6.74578e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5857245.463773653
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -6.84802e+06 trial_f -5.85725e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5827528.932392879
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -6.84802e+06 trial_f -5.82753e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6554435.39659416
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -6.84802e+06 trial_f -6.55444e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6543219.166125189
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -6.84802e+06 trial_f -6.54322e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6792467.362968652
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -6.84802e+06 trial_f -6.79247e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6543415.038199058
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -6.84802e+06 trial_f -6.54342e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6014250.016017889
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -6.84802e+06 trial_f -6.01425e+06 accepted 0  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.857636378
#             Iterations: 13
#             Function evaluations: 89
#             Gradient evaluations: 12
# basinhopping step 11: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6767195.393679231
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -6.84802e+06 trial_f -6.7672e+06 accepted 0  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.857636312
#             Iterations: 12
#             Function evaluations: 85
#             Gradient evaluations: 12
# basinhopping step 13: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6821676.011345986
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -6.84802e+06 trial_f -6.82168e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5841435.340508389
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -6.84802e+06 trial_f -5.84144e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 86: f -6.84802e+06 trial_f -6.41001e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6470136.253035947
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 87: f -6.84802e+06 trial_f -6.47014e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6345301.098578839
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 88: f -6.84802e+06 trial_f -6.3453e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5770019.240424961
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 89: f -6.84802e+06 trial_f -5.77002e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6479774.4734762255
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 90: f -6.84802e+06 trial_f -6.47977e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6830518.95051601
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 91: f -6.84802e+06 trial_f -6.83052e+06 accepted 0  lowest_f -6.84802e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6848018.857636357
#             Iterations: 11
#             Function evaluations: 80
#             Gradient evaluations: 11
# basinhopping step 92: f -6.84802e+06 trial_f -6.84802e+06 accepted 1  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5526089.03281058
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 93: f -6.84802e+06 trial_f -5.52609e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6051996.468941263
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 94: f -6.84802e+06 trial_f -6.052e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5911636.742358569
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 95: f -6.84802e+06 trial_f -5.91164e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5949978.034475623
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 96: f -6.84802e+06 trial_f -5.94998e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6839853.500727396
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 97: f -6.84802e+06 trial_f -6.83985e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5632475.307674505
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 98: f -6.84802e+06 trial_f -5.63248e+06 accepted 0  lowest_f -6.84802e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6659735.532964293
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 99: f -6.84802e+06 trial_f -6.65974e+06 accepted 0  lowest_f -6.84802e+06
# adaptive stepsize: acceptance rate 0.140000 target 0.500000 new stepsize 0.405 old stepsize 0.45
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -6597211.344689629
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 100: f -6.84802e+06 trial_f -6.59721e+06 accepted 0  lowest_f -6.84802e+06
# Optimised  Parameters:
# Turbine 0 parameter yaw_angle = 1.0607120580332708e-07
# Turbine 1 parameter yaw_angle = -1.2044800677738949e-08
# Turbine 2 parameter yaw_angle = -7.649240574294732e-09
# Turbine 3 parameter yaw_angle = -1.6056261004880804e-08
# Initial Power Output = 6.84801885763636 MW
# Optimised, Power Output = 6.848018857636381 MW
# Power increased by 3.1279731644239965e-13%
# Time to optimise wake = 17.328860759735107 s
# '\nnum_iterations = len(loc_data[1])\niteration = np.int(num_iterations / 2)\nloc_yaw_subopt_power = loc_yaw_data[2][iteration - 1]\nloc_yaw_subopt_params = loc_yaw_data[3][iteration - 1]\noptimisation_manager.print_output(floris, loc_yaw_data, loc_yaw_subopt_params, init_power, loc_yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)\n'

# %% [markdown]
# ## Optimise Power Output for Yaw Angle Only with Basin-Hopping

# %%
# set variable(s) to optimise for
yaw_floris = Floris('{}.json'.format(case))
yaw_variables=['yaw_angle']

# set bounds for the optimization on the turbine parameters (radians for angles)
minimum_values = [-0.5]
maximum_values = [0.5]

# compute the optimal yaw angles
yaw_opt_params, yaw_opt_power, yaw_data = optimisation_manager.optimise_func(yaw_floris, yaw_variables, minimum_values, maximum_values, yaw_name, case, global_search=True)

# print output at halfway iteration
"""
num_iterations = len(loc_data[1])
iteration = np.int(num_iterations / 2)
yaw_subopt_power = data[2][iteration - 1]
yaw_subopt_params = data[3][iteration - 1]
optimisation_manager.print_output(yaw_floris, data, yaw_subopt_params, init_power, yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)
"""
# Out:
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5102218.332510335
#             Iterations: 1
#             Function evaluations: 6
#             Gradient evaluations: 1
# basinhopping step 0: f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5267807.626687661
#             Iterations: 8
#             Function evaluations: 27
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -5.26781e+06 trial_f -5.26781e+06 accepted 1  lowest_f -5.26781e+06
# found new global minimum on step 1 with function value -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5036887.244491175
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -5.26781e+06 trial_f -5.03689e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5226047.219949355
#             Iterations: 8
#             Function evaluations: 28
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -5.26781e+06 trial_f -5.22605e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4897852.478063178
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -5.26781e+06 trial_f -4.89785e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4810524.552226281
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -5.26781e+06 trial_f -4.81052e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4939469.461214516
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -5.26781e+06 trial_f -4.93947e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5193203.261258459
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -5.26781e+06 trial_f -5.1932e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5101634.629631786
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -5.26781e+06 trial_f -5.10163e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5126396.410677465
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -5.26781e+06 trial_f -5.1264e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5183794.105382057
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -5.26781e+06 trial_f -5.18379e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5123592.841257477
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -5.26781e+06 trial_f -5.12359e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5124026.455071797
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -5.26781e+06 trial_f -5.12403e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5182446.8624832835
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -5.26781e+06 trial_f -5.18245e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5227685.078365183
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -5.26781e+06 trial_f -5.22769e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5204235.421079523
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -5.26781e+06 trial_f -5.20424e+06 accepted 0  lowest_f -5.26781e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5291321.26539481
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -5.29132e+06 trial_f -5.29132e+06 accepted 1  lowest_f -5.29132e+06
# found new global minimum on step 16 with function value -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5186017.01812014
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -5.29132e+06 trial_f -5.18602e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5129262.425382653
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -5.29132e+06 trial_f -5.12926e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5283040.376156874
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -5.29132e+06 trial_f -5.28304e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4877835.670313941
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -5.29132e+06 trial_f -4.87784e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5091540.868509261
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -5.29132e+06 trial_f -5.09154e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5140723.566037769
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -5.29132e+06 trial_f -5.14072e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4989361.431216125
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -5.29132e+06 trial_f -4.98936e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5254304.676417255
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -5.29132e+06 trial_f -5.2543e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5195300.544085667
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -5.29132e+06 trial_f -5.1953e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5162110.999235529
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -5.29132e+06 trial_f -5.16211e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5231630.602391359
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -5.29132e+06 trial_f -5.23163e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5161142.993724691
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -5.29132e+06 trial_f -5.16114e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5127278.228775822
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -5.29132e+06 trial_f -5.12728e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5179582.845603757
#             Iterations: 8
#             Function evaluations: 27
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 30: f -5.29132e+06 trial_f -5.17958e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5098949.776701163
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 31: f -5.29132e+06 trial_f -5.09895e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5259293.823294079
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -5.29132e+06 trial_f -5.25929e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5179414.701306462
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -5.29132e+06 trial_f -5.17941e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5023721.649331112
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 34: f -5.29132e+06 trial_f -5.02372e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5115055.804461722
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -5.29132e+06 trial_f -5.11506e+06 accepted 0  lowest_f -5.29132e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5084003.129791745
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 36: f -5.29132e+06 trial_f -5.084e+06 accepted 0  lowest_f -5.29132e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value:
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 100: f -5.31422e+06 trial_f -5.08177e+06 accepted 0  lowest_f -5.31422e+06
# Optimised  Parameters:
# Turbine 0 parameter yaw_angle = 0.5
# Turbine 1 parameter yaw_angle = 0.5
# Turbine 2 parameter yaw_angle = 0.02529126534375184
# Turbine 3 parameter yaw_angle = 0.013964325726243523
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 5.314219560803555 MW
# Power increased by 4.155079506151066%
# Time to optimise wake = 12.479946851730347 s
# '\nnum_iterations = len(loc_data[1])\niteration = np.int(num_iterations / 2)\nyaw_subopt_power = data[2][iteration - 1]\nyaw_subopt_params = data[3][iteration - 1]\noptimisation_manager.print_output(yaw_floris, data, yaw_subopt_params, init_power, yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)\n'

# %% [markdown]
# ## Evolution of Location Optimisation

# %%
# print evolution of optimised turbine locations

num_iterations = len(loc_data[1])
increment = np.int(num_iterations / 100)
for i in range(0, num_iterations, increment):
    floris_viz = optimisation_manager.set_iteration_data(loc_data[3][i], floris, loc_variables)
    flow_field_viz = floris_viz.farm.flow_field
    visualization_manager = VisualizationManager(flow_field_viz, loc_name, plot_wakes=False)
    visualization_manager.plot_z_planes([0.5])

# %% [markdown]
# ## Wake vs Flow Direction

# %%
imp.reload(optimisation_manager)
direction_floris = Floris('{}.json'.format(case))
direction_name = '{}_direction'.format(case)

turbines = [turbine for _, turbine in direction_floris.farm.flow_field.turbine_map.items()]
num_turbines = len(turbines)

for d in range(-60, 60, 10):
    #direction_floris.farm.flow_field.wind_direction = np.float(d)
    optimisation_manager.set_turbine_attr_vec(np.repeat(range(num_turbines), 1), np.repeat(turbines, 1), \
                     np.repeat(range(1), num_turbines, axis=0), np.repeat(['yaw_angle'], num_turbines, axis=0), \
                     np.ones(num_turbines) * np.radians(d), num_turbines)
    direction_floris.farm.flow_field.calculate_wake()
    flow_field_viz = direction_floris.farm.flow_field
    visualization_manager = VisualizationManager(flow_field_viz, direction_name, plot_wakes=True)
    print('Direction = {} degrees'.format(d))
    visualization_manager.plot_z_planes([0.5])
# Out:
# ../imperial_floris/turbine.py:149: RuntimeWarning: invalid value encountered in double_scalars
#   * np.cos(self.tilt_angle)**self.pT
# ../imperial_floris/wake_deflection.py:128: RuntimeWarning: invalid value encountered in sqrt
#   ln_deltaNum = (1.6+np.sqrt(M0))*(1.6*np.sqrt(sigma_y*sigma_z/(sigma_y0*sigma_z0)) - np.sqrt(M0))
# ../imperial_floris/wake_deflection.py:129: RuntimeWarning: invalid value encountered in sqrt
#   ln_deltaDen = (1.6-np.sqrt(M0))*(1.6*np.sqrt(sigma_y*sigma_z/(sigma_y0*sigma_z0)) + np.sqrt(M0))
# ../imperial_floris/wake_deflection.py:130: RuntimeWarning: invalid value encountered in sqrt
#   delta_far_wake = delta0 + (theta_c0*E0/5.2)*np.sqrt(sigma_y0*sigma_z0/(ky*kz*M0))*np.log(ln_deltaNum/ln_deltaDen) + ( ad + bd*(x_locations-coord.x) )
# ../imperial_floris/wake_deflection.py:130: RuntimeWarning: invalid value encountered in log
#   delta_far_wake = delta0 + (theta_c0*E0/5.2)*np.sqrt(sigma_y0*sigma_z0/(ky*kz*M0))*np.log(ln_deltaNum/ln_deltaDen) + ( ad + bd*(x_locations-coord.x) )
# ../imperial_floris/wake_velocity.py:244: RuntimeWarning: invalid value encountered in sqrt
#   velDef1 = (U_local*(1-np.sqrt(1-((Ct*np.cos(yaw))/(8.0*sigma_y*sigma_z/D**2)) ) )*totGauss)
# ../imperial_floris/wake_deflection.py:120: RuntimeWarning: invalid value encountered in greater
#   delta_near_wake[x_locations > x0] = 0.0
# ../imperial_floris/wake_deflection.py:125: RuntimeWarning: invalid value encountered in less
#   sigma_y[x_locations < x0] = sigma_y0[x_locations < x0]
# ../imperial_floris/wake_deflection.py:126: RuntimeWarning: invalid value encountered in less
#   sigma_z[x_locations < x0] = sigma_z0[x_locations < x0]
# ../imperial_floris/wake_deflection.py:131: RuntimeWarning: invalid value encountered in less_equal
#   delta_far_wake[x_locations <= x0] = 0.0
# ../imperial_floris/wake_velocity.py:228: RuntimeWarning: invalid value encountered in greater
#   velDef[x_locations > x0] = 0
# ../imperial_floris/wake_velocity.py:234: RuntimeWarning: invalid value encountered in less
#   sigma_y[x_locations < x0] = sigma_y0[x_locations < x0]
# ../imperial_floris/wake_velocity.py:235: RuntimeWarning: invalid value encountered in less
#   sigma_z[x_locations < x0] = sigma_z0[x_locations < x0]
# ../imperial_floris/wake_velocity.py:245: RuntimeWarning: invalid value encountered in less
#   velDef1[x_locations < x0] = 0
# ../imperial_floris/wake_velocity.py:226: RuntimeWarning: invalid value encountered in sqrt
#   velDef = (U_local*(1-np.sqrt(1-((Ct*np.cos(yaw))/(8.0*sigma_y*sigma_z/D**2)) ) )*totGauss)
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# /usr/local/lib/python3.7/site-packages/matplotlib/contour.py:1480: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# /usr/local/lib/python3.7/site-packages/matplotlib/contour.py:1481: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# /usr/local/lib/python3.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# posx and posy should be finite values
# Direction = -60 degrees
# posx and posy should be finite values
# posx and posy should be finite values
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py:416: RuntimeWarning: invalid value encountered in double_scalars
#   return points[1, 0] - points[0, 0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2220                 bbox_filtered = []
#    2221                 for a in bbox_artists:
# -> 2222                     bbox = a.get_window_extent(renderer)
#    2223                     if a.get_clip_on():
#    2224                         clip_box = a.get_clip_box()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     569
#     570     def get_window_extent(self, renderer=None):
# --> 571         return self.get_path().get_extents(self.get_transform())
#     572
#     573
#
# /usr/local/lib/python3.7/site-packages/matplotlib/path.py in get_extents(self, transform)
#     531         path = self
#     532         if transform is not None:
# --> 533             transform = transform.frozen()
#     534             if not transform.is_affine:
#     535                 path = self.transformed(transform)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in frozen(self)
#    2240
#    2241     def frozen(self):
# -> 2242         return blended_transform_factory(self._x.frozen(), self._y.frozen())
#    2243     frozen.__doc__ = Transform.frozen.__doc__
#    2244
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in blended_transform_factory(x_transform, y_transform)
#    2387     if (isinstance(x_transform, Affine2DBase)
#    2388         and isinstance(y_transform, Affine2DBase)):
# -> 2389         return BlendedAffine2D(x_transform, y_transform)
#    2390     return BlendedGenericTransform(x_transform, y_transform)
#    2391
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in __init__(self, x_transform, y_transform, **kwargs)
#    2328         is_correct = is_affine and is_separable
#    2329         if not is_correct:
# -> 2330             raise ValueError("Both *x_transform* and *y_transform* must be 2D "
#    2331                              "affine transforms")
#    2332
#
# ValueError: Both *x_transform* and *y_transform* must be 2D affine transforms
# Direction = -50 degrees
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2220                 bbox_filtered = []
#    2221                 for a in bbox_artists:
# -> 2222                     bbox = a.get_window_extent(renderer)
#    2223                     if a.get_clip_on():
#    2224                         clip_box = a.get_clip_box()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     569
#     570     def get_window_extent(self, renderer=None):
# --> 571         return self.get_path().get_extents(self.get_transform())
#     572
#     573
#
# /usr/local/lib/python3.7/site-packages/matplotlib/path.py in get_extents(self, transform)
#     531         path = self
#     532         if transform is not None:
# --> 533             transform = transform.frozen()
#     534             if not transform.is_affine:
#     535                 path = self.transformed(transform)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in frozen(self)
#    2240
#    2241     def frozen(self):
# -> 2242         return blended_transform_factory(self._x.frozen(), self._y.frozen())
#    2243     frozen.__doc__ = Transform.frozen.__doc__
#    2244
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in blended_transform_factory(x_transform, y_transform)
#    2387     if (isinstance(x_transform, Affine2DBase)
#    2388         and isinstance(y_transform, Affine2DBase)):
# -> 2389         return BlendedAffine2D(x_transform, y_transform)
#    2390     return BlendedGenericTransform(x_transform, y_transform)
#    2391
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in __init__(self, x_transform, y_transform, **kwargs)
#    2328         is_correct = is_affine and is_separable
#    2329         if not is_correct:
# -> 2330             raise ValueError("Both *x_transform* and *y_transform* must be 2D "
#    2331                              "affine transforms")
#    2332
#
# ValueError: Both *x_transform* and *y_transform* must be 2D affine transforms
# posx and posy should be finite values
# Direction = -40 degrees
# posx and posy should be finite values
# posx and posy should be finite values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2220                 bbox_filtered = []
#    2221                 for a in bbox_artists:
# -> 2222                     bbox = a.get_window_extent(renderer)
#    2223                     if a.get_clip_on():
#    2224                         clip_box = a.get_clip_box()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     569
#     570     def get_window_extent(self, renderer=None):
# --> 571         return self.get_path().get_extents(self.get_transform())
#     572
#     573
#
# /usr/local/lib/python3.7/site-packages/matplotlib/path.py in get_extents(self, transform)
#     531         path = self
#     532         if transform is not None:
# --> 533             transform = transform.frozen()
#     534             if not transform.is_affine:
#     535                 path = self.transformed(transform)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in frozen(self)
#    2240
#    2241     def frozen(self):
# -> 2242         return blended_transform_factory(self._x.frozen(), self._y.frozen())
#    2243     frozen.__doc__ = Transform.frozen.__doc__
#    2244
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in blended_transform_factory(x_transform, y_transform)
#    2387     if (isinstance(x_transform, Affine2DBase)
#    2388         and isinstance(y_transform, Affine2DBase)):
# -> 2389         return BlendedAffine2D(x_transform, y_transform)
#    2390     return BlendedGenericTransform(x_transform, y_transform)
#    2391
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in __init__(self, x_transform, y_transform, **kwargs)
#    2328         is_correct = is_affine and is_separable
#    2329         if not is_correct:
# -> 2330             raise ValueError("Both *x_transform* and *y_transform* must be 2D "
#    2331                              "affine transforms")
#    2332
#
# ValueError: Both *x_transform* and *y_transform* must be 2D affine transforms
# ../imperial_floris/wake_deflection.py:92: RuntimeWarning: divide by zero encountered in true_divide
#   uR          = U_local*Ct*np.cos(tilt)*np.cos(yaw)/(2.*(1-np.sqrt(1-(Ct*np.cos(tilt)*np.cos(yaw)))))
# ../imperial_floris/wake_deflection.py:128: RuntimeWarning: invalid value encountered in true_divide
#   ln_deltaNum = (1.6+np.sqrt(M0))*(1.6*np.sqrt(sigma_y*sigma_z/(sigma_y0*sigma_z0)) - np.sqrt(M0))
# ../imperial_floris/wake_deflection.py:129: RuntimeWarning: invalid value encountered in true_divide
#   ln_deltaDen = (1.6-np.sqrt(M0))*(1.6*np.sqrt(sigma_y*sigma_z/(sigma_y0*sigma_z0)) + np.sqrt(M0))
# ../imperial_floris/wake_deflection.py:130: RuntimeWarning: invalid value encountered in multiply
#   delta_far_wake = delta0 + (theta_c0*E0/5.2)*np.sqrt(sigma_y0*sigma_z0/(ky*kz*M0))*np.log(ln_deltaNum/ln_deltaDen) + ( ad + bd*(x_locations-coord.x) )
# ../imperial_floris/wake_velocity.py:191: RuntimeWarning: divide by zero encountered in true_divide
#   uR      = U_local*Ct*np.cos(tilt)*np.cos(yaw)/(2.*(1-np.sqrt(1-(Ct*np.cos(tilt)*np.cos(yaw)))))
# Direction = -30 degrees
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/Cellar/ipython/6.4.0_1/libexec/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2220                 bbox_filtered = []
#    2221                 for a in bbox_artists:
# -> 2222                     bbox = a.get_window_extent(renderer)
#    2223                     if a.get_clip_on():
#    2224                         clip_box = a.get_clip_box()
#
# /usr/local/lib/python3.7/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     569
#     570     def get_window_extent(self, renderer=None):
# --> 571         return self.get_path().get_extents(self.get_transform())
#     572
#     573
#
# /usr/local/lib/python3.7/site-packages/matplotlib/path.py in get_extents(self, transform)
#     531         path = self
#     532         if transform is not None:
# --> 533             transform = transform.frozen()
#     534             if not transform.is_affine:
#     535                 path = self.transformed(transform)
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in frozen(self)
#    2240
#    2241     def frozen(self):
# -> 2242         return blended_transform_factory(self._x.frozen(), self._y.frozen())
#    2243     frozen.__doc__ = Transform.frozen.__doc__
#    2244
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in blended_transform_factory(x_transform, y_transform)
#    2387     if (isinstance(x_transform, Affine2DBase)
#    2388         and isinstance(y_transform, Affine2DBase)):
# -> 2389         return BlendedAffine2D(x_transform, y_transform)
#    2390     return BlendedGenericTransform(x_transform, y_transform)
#    2391
#
# /usr/local/lib/python3.7/site-packages/matplotlib/transforms.py in __init__(self, x_transform, y_transform, **kwargs)
#    2328         is_correct = is_affine and is_separable
#    2329         if not is_correct:
# -> 2330             raise ValueError("Both *x_transform* and *y_transform* must be 2D "
#    2331                              "affine transforms")
#    2332
#
# ValueError: Both *x_transform* and *y_transform* must be 2D affine transforms
# Direction = -20 degrees
# Direction = -10 degrees
