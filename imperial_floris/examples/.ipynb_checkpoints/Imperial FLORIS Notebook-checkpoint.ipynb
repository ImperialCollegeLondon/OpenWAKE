# %%
# load modules
import sys
sys.path.append('../')
from imperial_floris.floris import Floris
import numpy as np
import matplotlib.pyplot as plt
from imperial_floris.visualization_manager import VisualizationManager
import imperial_floris.optimisation_manager as optimisation_manager  # MODIFIED modules used for optimizing FLORIS
import imp
import time
import copy

# See https://v2.overleaf.com/16702532wdkvyywcgsxh#!#%2F64036805%2F for more information

# %% [markdown]
# ## Specify Case Study, Initialise File Names

# %%
# specify case study
case = 'case2'

# specify case file names
init_name = '{}_init'.format(case)
loc_name = '{}_loc'.format(case)
yaw_name = '{}_yaw'.format(case)
loc_yaw_name = '{}_loc_yaw'.format(case)
direction_name = '{}'

# %% [markdown]
# ## No Optimisation

# %%
# start timer
t1 = time.time()
init_floris = Floris('{}.json'.format(case))
num_turbines = len(init_floris.farm.flow_field.turbine_map.turbine_map)

# determine initial power production
init_floris.farm.flow_field.calculate_wake()

# end timer and print time difference
t2 = time.time()
print('Time to compute wake = ', t2-t1, 's')

# calculate initial power and print
init_power = optimisation_manager.calc_power(init_floris)[1]
print('Initial Power Output = ', init_power/10**6, ' MW')

# plot initial wake_field
ff_viz = init_floris.farm.flow_field
visualization_manager = VisualizationManager(ff_viz, init_name, plot_wakes=True)
visualization_manager.plot_z_planes([0.5])
visualization_manager.plot_x_planes([0.5])
# Out:
# Time to compute wake =  0.036299705505371094 s
# Initial Power Output =  5.102218332510335  MW

# %% [markdown]
# ## Optimise Power Output for Turbine Locations Only with Basin-Hopping

# %%
imp.reload(optimisation_manager)
loc_floris = Floris('{}.json'.format(case))
loc_variables=['layout_x', 'layout_y']

# set bounds for the optimization on the turbine locations
minimum_values = [0.0, 0.0]
maximum_values = [1000.0, 1000.0]

# compute the optimal turbine locations
loc_opt_params, loc_opt_power, loc_data = optimisation_manager.optimise_func(loc_floris, loc_variables, minimum_values, maximum_values, loc_name, case, global_search=True)
print(optimisation_manager.calc_power(loc_floris))
# print output at half-way iteration
"""
num_iterations = len(loc_data[1])
iteration = np.int(num_iterations / 2)
loc_subopt_power = loc_data[2][iteration - 1]
loc_subopt_params = loc_data[3][iteration - 1]
optimisation_manager.print_output(loc_floris, loc_data, loc_subopt_params, init_power, loc_subopt_power, loc_variables, num_turbines, is_opt=False, plot_wakes=True)
"""
# Out:
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  8
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5316691.15127381
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 0: f -5.31669e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563451367
#             Iterations: 28
#             Function evaluations: 298
#             Gradient evaluations: 28
# basinhopping step 1: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# found new global minimum on step 1 with function value -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564853996
#             Iterations: 4
#             Function evaluations: 51
#             Gradient evaluations: 4
# basinhopping step 2: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# found new global minimum on step 2 with function value -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.562914226
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 3: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563337935
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 4: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.557961547
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 5: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.558076173
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 6: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564615348
#             Iterations: 6
#             Function evaluations: 76
#             Gradient evaluations: 6
# basinhopping step 7: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.554186614
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 8: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563586126
#             Iterations: 4
#             Function evaluations: 41
#             Gradient evaluations: 4
# basinhopping step 9: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563207828
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 10: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563755391
#             Iterations: 4
#             Function evaluations: 41
#             Gradient evaluations: 4
# basinhopping step 11: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.562417762
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 12: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564485577
#             Iterations: 2
#             Function evaluations: 31
#             Gradient evaluations: 2
# basinhopping step 13: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563064776
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 14: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564803857
#             Iterations: 4
#             Function evaluations: 52
#             Gradient evaluations: 4
# basinhopping step 15: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.559337381
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 16: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564633906
#             Iterations: 2
#             Function evaluations: 31
#             Gradient evaluations: 2
# basinhopping step 17: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.562455654
#             Iterations: 4
#             Function evaluations: 40
#             Gradient evaluations: 4
# basinhopping step 18: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.56379368
#             Iterations: 6
#             Function evaluations: 63
#             Gradient evaluations: 6
# basinhopping step 19: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.562459169
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 20: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564847789
#             Iterations: 7
#             Function evaluations: 81
#             Gradient evaluations: 7
# basinhopping step 21: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.562523374
#             Iterations: 3
#             Function evaluations: 30
#             Gradient evaluations: 3
# basinhopping step 22: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563197225
#             Iterations: 1
#             Function evaluations: 10
#             Gradient evaluations: 1
# basinhopping step 23: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.557252357
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 24: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.563916427
#             Iterations: 4
#             Function evaluations: 53
#             Gradient evaluations: 4
# basinhopping step 25: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.560262764
#             Iterations: 2
#             Function evaluations: 20
#             Gradient evaluations: 2
# basinhopping step 26: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564613325
#             Iterations: 5
#             Function evaluations: 64
#             Gradient evaluations: 5
# basinhopping step 27: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -6845040.564803113
#             Iterations: 3
#             Function evaluations: 41
#             Gradient evaluations: 3
# basinhopping step 28: f -6.84504e+06 trial_f -6.84504e+06 accepted 1  lowest_f -6.84504e+06
# Optimised  Parameters:
# Turbine (794.0803714361982, 1000.0) parameter layout_x = 794.0803714361982
# Turbine (794.0807492344126, 0.0) parameter layout_x = 794.0807492344126
# Turbine (799.6430385914779, 199.66758255483182) parameter layout_x = 799.6430385914779
# Turbine (800.3631436543018, 800.7109852793691) parameter layout_x = 800.3631436543018
# Turbine (794.0803714361982, 1000.0) parameter layout_y = 1000.0
# Turbine (794.0807492344126, 0.0) parameter layout_y = 0.0
# Turbine (799.6430385914779, 199.66758255483182) parameter layout_y = 199.66758255483182
# Turbine (800.3631436543018, 800.7109852793691) parameter layout_y = 800.7109852793691
# Turbine (794.0803714361982, 1000.0) Power Output = 1712005.1679717556 MW
# Turbine (794.0807492344126, 0.0) Power Output = 1712005.1679717556 MW
# Turbine (799.6430385914779, 199.66758255483182) Power Output = 1710515.1144209472 MW
# Turbine (800.3631436543018, 800.7109852793691) Power Output = 1710515.114438655 MW
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 6.8450405648539965 MW
# Power increased by 34.15812728433707%
# Time to optimise wake = 11.6548490524292 s
# ([1712005.1679717556, 1712005.1679717556, 1710515.1144209472, 1710515.114438655], 6845040.564803113)
# '\nnum_iterations = len(loc_data[1])\niteration = np.int(num_iterations / 2)\nloc_subopt_power = loc_data[2][iteration - 1]\nloc_subopt_params = loc_data[3][iteration - 1]\noptimisation_manager.print_output(loc_floris, loc_data, loc_subopt_params, init_power, loc_subopt_power, loc_variables, num_turbines, is_opt=False, plot_wakes=True)\n'

# %% [markdown]
# ## Optimise Power Output for Yaw Angle (for $300^\circ$) after Turbine Location (for $270^\circ$) with Basin-Hopping

# %%
# set variable(s) to optimise for
imp.reload(optimisation_manager)
yaw_variables=['yaw_angle']

# set bounds for the optimization on the turbine parameters (radians for angles)
minimum_values = [-1]
maximum_values = [1]

# compute the optimal yaw angles
loc_floris.farm.flow_field.wind_direction = np.radians(300.0)
loc_yaw_opt_params, loc_yaw_opt_power, loc_yaw_data = optimisation_manager.optimise_func(loc_floris, yaw_variables, minimum_values, maximum_values, loc_yaw_name, case, global_search=True)

# print output at halfway iteration
"""
num_iterations = len(loc_data[1])
iteration = np.int(num_iterations / 2)
loc_yaw_subopt_power = loc_yaw_data[2][iteration - 1]
loc_yaw_subopt_params = loc_yaw_data[3][iteration - 1]
optimisation_manager.print_output(floris, loc_yaw_data, loc_yaw_subopt_params, init_power, loc_yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)
"""
# Out:
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5410530.145342668
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -5.41053e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5368328.944977757
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -5.41053e+06 trial_f -5.36833e+06 accepted 0  lowest_f -5.41053e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5045366.709883712
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -5.41053e+06 trial_f -5.04537e+06 accepted 0  lowest_f -5.41053e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5423811.847083423
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -5.42381e+06 trial_f -5.42381e+06 accepted 1  lowest_f -5.42381e+06
# found new global minimum on step 3 with function value -5.42381e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5430002.576535028
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -5.43e+06 trial_f -5.43e+06 accepted 1  lowest_f -5.43e+06
# found new global minimum on step 4 with function value -5.43e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5408074.369342984
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -5.43e+06 trial_f -5.40807e+06 accepted 0  lowest_f -5.43e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5283230.081657581
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -5.43e+06 trial_f -5.28323e+06 accepted 0  lowest_f -5.43e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5155172.712816997
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -5.43e+06 trial_f -5.15517e+06 accepted 0  lowest_f -5.43e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4833042.826953214
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -5.43e+06 trial_f -4.83304e+06 accepted 0  lowest_f -5.43e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4937777.239203044
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -5.43e+06 trial_f -4.93778e+06 accepted 0  lowest_f -5.43e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5390364.2728732815
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -5.43e+06 trial_f -5.39036e+06 accepted 0  lowest_f -5.43e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5503245.245538306
#             Iterations: 12
#             Function evaluations: 87
#             Gradient evaluations: 12
# basinhopping step 11: f -5.50325e+06 trial_f -5.50325e+06 accepted 1  lowest_f -5.50325e+06
# found new global minimum on step 11 with function value -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5022780.054289243
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -5.50325e+06 trial_f -5.02278e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5296002.741122579
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -5.50325e+06 trial_f -5.296e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4973149.738272053
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -5.50325e+06 trial_f -4.97315e+06 accepted 0  lowest_f -5.50325e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5503245.24553837
#             Iterations: 10
#             Function evaluations: 73
#             Gradient evaluations: 10
# basinhopping step 15: f -5.50325e+06 trial_f -5.50325e+06 accepted 1  lowest_f -5.50325e+06
# found new global minimum on step 15 with function value -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5017917.606339019
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -5.50325e+06 trial_f -5.01792e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5220929.699366532
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -5.50325e+06 trial_f -5.22093e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4929457.439485125
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -5.50325e+06 trial_f -4.92946e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4752467.235225361
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -5.50325e+06 trial_f -4.75247e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5436859.413761426
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -5.50325e+06 trial_f -5.43686e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5174864.604317624
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -5.50325e+06 trial_f -5.17486e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5124858.26603971
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -5.50325e+06 trial_f -5.12486e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5331556.117163667
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -5.50325e+06 trial_f -5.33156e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4914412.058418238
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -5.50325e+06 trial_f -4.91441e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5037473.626562024
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -5.50325e+06 trial_f -5.03747e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5486191.97285137
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -5.50325e+06 trial_f -5.48619e+06 accepted 0  lowest_f -5.50325e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5503245.245538224
#             Iterations: 13
#             Function evaluations: 91
#             Gradient evaluations: 13
# basinhopping step 27: f -5.50325e+06 trial_f -5.50325e+06 accepted 1  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5273561.422120339
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -5.50325e+06 trial_f -5.27356e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4958623.305508443
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -5.50325e+06 trial_f -4.95862e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5352210.084384872
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 30: f -5.50325e+06 trial_f -5.35221e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4903022.653593519
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 31: f -5.50325e+06 trial_f -4.90302e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5182951.719489845
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -5.50325e+06 trial_f -5.18295e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5391412.90192718
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -5.50325e+06 trial_f -5.39141e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5375225.79595691
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 34: f -5.50325e+06 trial_f -5.37523e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4845415.298867855
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -5.50325e+06 trial_f -4.84542e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5119757.883695915
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 36: f -5.50325e+06 trial_f -5.11976e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5198089.654372426
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -5.50325e+06 trial_f -5.19809e+06 accepted 0  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5221792.988482812
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 38: f -5.50325e+06 trial_f -5.22179e+06 accepted 0  lowest_f -5.50325e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5503245.245538332
#             Iterations: 13
#             Function evaluations: 88
#             Gradient evaluations: 12
# basinhopping step 39: f -5.50325e+06 trial_f -5.50325e+06 accepted 1  lowest_f -5.50325e+06
# ../imperial_floris/wake_velocity.py:226: RuntimeWarning: invalid value encountered in sqrt
#   velDef = (U_local*(1-np.sqrt(1-((Ct*np.cos(yaw))/(8.0*sigma_y*sigma_z/D**2)) ) )*totGauss)
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5503245.245538363
#             Iterations: 12
#             Function evaluations: 81
#             Gradient evaluations: 11
# basinhopping step 40: f -5.50325e+06 trial_f -5.50325e+06 accepted 1  lowest_f -5.50325e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4783613.064126679
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 41: f -5.50325e+06 trial_f -4.78361e+06 accepted 0  lowest_f -5.50325e+06
# Optimised  Parameters:
# Turbine (794.0803714361982, 1000.0) parameter yaw_angle = -1.589668263926483e-09
# Turbine (794.0807492344126, 0.0) parameter yaw_angle = 0.12126313977205039
# Turbine (799.6430385914779, 199.66758255483182) parameter yaw_angle = 5.682132443948377e-09
# Turbine (800.3631436543018, 800.7109852793691) parameter yaw_angle = 0.30839663089813407
# Turbine (794.0803714361982, 1000.0) Power Output = 482531.67238916253 MW
# Turbine (794.0807492344126, 0.0) Power Output = 1514291.7795491046 MW
# Turbine (799.6430385914779, 199.66758255483182) Power Output = 1127667.508909912 MW
# Turbine (800.3631436543018, 800.7109852793691) Power Output = 1659122.10536547 MW
# Initial Power Output = 6.845040564803114 MW
# Optimised, Power Output = 5.50324524553837 MW
# Power increased by -19.602445106961%
# Time to optimise wake = 8.348618984222412 s
# '\nnum_iterations = len(loc_data[1])\niteration = np.int(num_iterations / 2)\nloc_yaw_subopt_power = loc_yaw_data[2][iteration - 1]\nloc_yaw_subopt_params = loc_yaw_data[3][iteration - 1]\noptimisation_manager.print_output(floris, loc_yaw_data, loc_yaw_subopt_params, init_power, loc_yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)\n'

# %% [markdown]
# ## Optimise Power Output for Yaw Angle Only with Basin-Hopping

# %%
# set variable(s) to optimise for
yaw_floris = Floris('{}.json'.format(case))
yaw_variables=['yaw_angle']

# set bounds for the optimization on the turbine parameters (radians for angles)
minimum_values = [-0.5]
maximum_values = [0.5]

# compute the optimal yaw angles
yaw_opt_params, yaw_opt_power, yaw_data = optimisation_manager.optimise_func(yaw_floris, yaw_variables, minimum_values, maximum_values, yaw_name, case, global_search=True)

# print output at halfway iteration
"""
num_iterations = len(loc_data[1])
iteration = np.int(num_iterations / 2)
yaw_subopt_power = data[2][iteration - 1]
yaw_subopt_params = data[3][iteration - 1]
optimisation_manager.print_output(yaw_floris, data, yaw_subopt_params, init_power, yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)
"""
# Out:
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5102218.332510335
#             Iterations: 1
#             Function evaluations: 6
#             Gradient evaluations: 1
# basinhopping step 0: f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5071359.493418431
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -5.10222e+06 trial_f -5.07136e+06 accepted 0  lowest_f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5091829.486294493
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -5.10222e+06 trial_f -5.09183e+06 accepted 0  lowest_f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5030369.209234446
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -5.10222e+06 trial_f -5.03037e+06 accepted 0  lowest_f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5069451.845315122
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -5.10222e+06 trial_f -5.06945e+06 accepted 0  lowest_f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5122429.727857984
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -5.12243e+06 trial_f -5.12243e+06 accepted 1  lowest_f -5.12243e+06
# found new global minimum on step 5 with function value -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5006797.014364103
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -5.12243e+06 trial_f -5.0068e+06 accepted 0  lowest_f -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5089206.049833814
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -5.12243e+06 trial_f -5.08921e+06 accepted 0  lowest_f -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4743126.2000190215
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -5.12243e+06 trial_f -4.74313e+06 accepted 0  lowest_f -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5012522.291066354
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -5.12243e+06 trial_f -5.01252e+06 accepted 0  lowest_f -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5020900.165853562
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -5.12243e+06 trial_f -5.0209e+06 accepted 0  lowest_f -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4979450.66813012
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -5.12243e+06 trial_f -4.97945e+06 accepted 0  lowest_f -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4742987.224302736
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -5.12243e+06 trial_f -4.74299e+06 accepted 0  lowest_f -5.12243e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5211438.58230305
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -5.21144e+06 trial_f -5.21144e+06 accepted 1  lowest_f -5.21144e+06
# found new global minimum on step 13 with function value -5.21144e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5212505.569015783
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -5.21251e+06 trial_f -5.21251e+06 accepted 1  lowest_f -5.21251e+06
# found new global minimum on step 14 with function value -5.21251e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5278052.193266731
#             Iterations: 9
#             Function evaluations: 34
#             Gradient evaluations: 5
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -5.27805e+06 trial_f -5.27805e+06 accepted 1  lowest_f -5.27805e+06
# found new global minimum on step 15 with function value -5.27805e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4910595.145587891
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -5.27805e+06 trial_f -4.9106e+06 accepted 0  lowest_f -5.27805e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5018856.806444765
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -5.27805e+06 trial_f -5.01886e+06 accepted 0  lowest_f -5.27805e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4894012.202450385
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -5.27805e+06 trial_f -4.89401e+06 accepted 0  lowest_f -5.27805e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5100986.48162961
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -5.27805e+06 trial_f -5.10099e+06 accepted 0  lowest_f -5.27805e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5232270.357196866
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -5.27805e+06 trial_f -5.23227e+06 accepted 0  lowest_f -5.27805e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5314600.087375041
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -5.3146e+06 trial_f -5.3146e+06 accepted 1  lowest_f -5.3146e+06
# found new global minimum on step 21 with function value -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4954812.605203508
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -5.3146e+06 trial_f -4.95481e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5107515.315622547
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -5.3146e+06 trial_f -5.10752e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5154237.012628634
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -5.3146e+06 trial_f -5.15424e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5293730.878346532
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -5.3146e+06 trial_f -5.29373e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4944101.453609118
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -5.3146e+06 trial_f -4.9441e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5161722.44706058
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -5.3146e+06 trial_f -5.16172e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5198292.528786136
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -5.3146e+06 trial_f -5.19829e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5026093.196554987
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -5.3146e+06 trial_f -5.02609e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5073035.626808467
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 30: f -5.3146e+06 trial_f -5.07304e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5014491.074839333
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 31: f -5.3146e+06 trial_f -5.01449e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4918104.192526066
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -5.3146e+06 trial_f -4.9181e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5166858.709480388
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -5.3146e+06 trial_f -5.16686e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5144732.3069034405
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 34: f -5.3146e+06 trial_f -5.14473e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5037060.584552205
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -5.3146e+06 trial_f -5.03706e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5007383.935652444
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 36: f -5.3146e+06 trial_f -5.00738e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5190475.95097731
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -5.3146e+06 trial_f -5.19048e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4907571.382504522
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 38: f -5.3146e+06 trial_f -4.90757e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4775742.463322503
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 39: f -5.3146e+06 trial_f -4.77574e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4915978.138879622
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 40: f -5.3146e+06 trial_f -4.91598e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5184244.405276493
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 41: f -5.3146e+06 trial_f -5.18424e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5207840.408335492
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 42: f -5.3146e+06 trial_f -5.20784e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4840471.960039149
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 43: f -5.3146e+06 trial_f -4.84047e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5036423.4796649795
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 44: f -5.3146e+06 trial_f -5.03642e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5163586.869332127
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 45: f -5.3146e+06 trial_f -5.16359e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4869708.484125106
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 46: f -5.3146e+06 trial_f -4.86971e+06 accepted 0  lowest_f -5.3146e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5042015.853327874
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 47: f -5.3146e+06 trial_f -5.04202e+06 accepted 0  lowest_f -5.3146e+06
# Optimised  Parameters:
# Turbine (200.0, 200.0) parameter yaw_angle = 0.5
# Turbine (200.0, 800.0) parameter yaw_angle = -0.5
# Turbine (800.0, 200.0) parameter yaw_angle = 0.009842267366507007
# Turbine (800.0, 800.0) parameter yaw_angle = 0.020751624289405496
# Turbine (200.0, 200.0) Power Output = 1339326.5652052267 MW
# Turbine (200.0, 800.0) Power Output = 1711865.0018158003 MW
# Turbine (800.0, 200.0) Power Output = 1305613.5528590567 MW
# Turbine (800.0, 800.0) Power Output = 685210.7240280807 MW
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 5.314600087375041 MW
# Power increased by 4.162537567462584%
# Time to optimise wake = 3.4364120960235596 s
# '\nnum_iterations = len(loc_data[1])\niteration = np.int(num_iterations / 2)\nyaw_subopt_power = data[2][iteration - 1]\nyaw_subopt_params = data[3][iteration - 1]\noptimisation_manager.print_output(yaw_floris, data, yaw_subopt_params, init_power, yaw_subopt_power, yaw_variables, num_turbines, is_opt=False, plot_wakes=True)\n'

# %% [markdown]
# ## Evolution of Optimisation

# %%
# reload optimisation_manager if edited
imp.reload(optimisation_manager)

# print evolution of optimised turbine locations

evolution_name = loc_yaw_name
evolution_data = loc_yaw_data
evolution_variables = yaw_variables
num_plots = 100

optimisation_manager.print_evolution(loc_floris, evolution_name, evolution_data, evolution_variables, num_plots)
# Out:
# Iteration #0, Total Power Output = 6.845040564803114 MW
# Iteration #6, Total Power Output = 5.41053014977347 MW
# Iteration #12, Total Power Output = 5.368328942832995 MW
# Iteration #18, Total Power Output = 5.04536671547032 MW
# Iteration #24, Total Power Output = 5.214653780443794 MW
# Iteration #30, Total Power Output = 5.4238118407570735 MW
# Iteration #36, Total Power Output = 5.105332809392011 MW
# Iteration #42, Total Power Output = 5.4300025818660105 MW
# Iteration #48, Total Power Output = 4.684296827250821 MW
# Iteration #54, Total Power Output = 5.408074365682542 MW
# Iteration #60, Total Power Output = 5.283230079427544 MW
# Iteration #66, Total Power Output = 5.1551727125279845 MW
# Iteration #72, Total Power Output = 4.833042830752861 MW
# Iteration #78, Total Power Output = 4.9377772283803925 MW
# Iteration #84, Total Power Output = 5.039265995096724 MW
# Iteration #90, Total Power Output = 5.390364272873281 MW
# Iteration #96, Total Power Output = 5.435783525881389 MW
# Iteration #102, Total Power Output = 5.46431613932104 MW
# Iteration #108, Total Power Output = 2.0607749327329556 MW
# Iteration #114, Total Power Output = 5.481328351749273 MW
# Iteration #120, Total Power Output = 5.489740083605399 MW
# Iteration #126, Total Power Output = 5.494456773333661 MW
# Iteration #132, Total Power Output = 5.492461206183695 MW
# Iteration #138, Total Power Output = 5.499935009203821 MW
# Iteration #144, Total Power Output = 5.502986516749591 MW
# Iteration #150, Total Power Output = 5.5032027415712275 MW
# Iteration #156, Total Power Output = 5.482592898658782 MW
# Iteration #162, Total Power Output = 5.503241689590489 MW
# Iteration #168, Total Power Output = 5.503245215543005 MW
# Iteration #174, Total Power Output = 5.503245245374912 MW
# Iteration #180, Total Power Output = 5.503245245538314 MW
# Iteration #186, Total Power Output = 5.022780057202383 MW
# Iteration #192, Total Power Output = 5.296002736636251 MW
# Iteration #198, Total Power Output = 4.973149745588991 MW
# Iteration #204, Total Power Output = 5.476725259562828 MW
# Iteration #210, Total Power Output = 5.493729105976212 MW
# Iteration #216, Total Power Output = 5.502395622703317 MW
# Iteration #222, Total Power Output = 2.8281205188696847 MW
# Iteration #228, Total Power Output = 5.503079359740425 MW
# Iteration #234, Total Power Output = 5.503240596627096 MW
# Iteration #240, Total Power Output = 5.503154480882312 MW
# Iteration #246, Total Power Output = 5.503241540791703 MW
# Iteration #252, Total Power Output = 5.503244224172819 MW
# Iteration #258, Total Power Output = 5.503245000582676 MW
# Iteration #264, Total Power Output = 5.503245241355771 MW
# Iteration #270, Total Power Output = 5.503245245538368 MW
# Iteration #276, Total Power Output = 5.017917593646381 MW
# Iteration #282, Total Power Output = 5.220929685843932 MW
# Iteration #288, Total Power Output = 4.929457423017604 MW
# Iteration #294, Total Power Output = 4.752467213428825 MW
# Iteration #300, Total Power Output = 5.1612345790874485 MW
# Iteration #306, Total Power Output = 5.43685941361128 MW
# Iteration #312, Total Power Output = 5.174864600847995 MW
# Iteration #318, Total Power Output = 5.1248582691724165 MW
# Iteration #324, Total Power Output = 5.331556113108586 MW
# Iteration #330, Total Power Output = 4.914412046945122 MW
# Iteration #336, Total Power Output = 5.0374736293620765 MW
# Iteration #342, Total Power Output = 5.320209528357241 MW
# Iteration #348, Total Power Output = 5.486191972851371 MW
# Iteration #354, Total Power Output = 5.232004358705762 MW
# Iteration #360, Total Power Output = 5.404901926993771 MW
# Iteration #366, Total Power Output = 2.0607748579741614 MW
# Iteration #372, Total Power Output = 5.470770642615388 MW
# Iteration #378, Total Power Output = 5.480970414553128 MW
# Iteration #384, Total Power Output = 5.500435043990336 MW
# Iteration #390, Total Power Output = 5.501873261276061 MW
# Iteration #396, Total Power Output = 5.48551787220911 MW
# Iteration #402, Total Power Output = 5.502972206727414 MW
# Iteration #408, Total Power Output = 5.502980533802228 MW
# Iteration #414, Total Power Output = 5.503209895934777 MW
# Iteration #420, Total Power Output = 5.503231466196803 MW
# Iteration #426, Total Power Output = 5.503245168275296 MW
# Iteration #432, Total Power Output = 5.503245244420427 MW
# Iteration #438, Total Power Output = 5.503245245538223 MW
# Iteration #444, Total Power Output = 5.2735614221203395 MW
# Iteration #450, Total Power Output = 4.958623305508443 MW
# Iteration #456, Total Power Output = 5.352210084384872 MW
# Iteration #462, Total Power Output = 4.903022653593519 MW
# Iteration #468, Total Power Output = 5.182951719489846 MW
# Iteration #474, Total Power Output = 5.39141290192718 MW
# Iteration #480, Total Power Output = 5.118117569622481 MW
# Iteration #486, Total Power Output = 2.0308263053407023 MW
# Iteration #492, Total Power Output = 5.375225799271837 MW
# Iteration #498, Total Power Output = 4.8454152878192245 MW
# Iteration #504, Total Power Output = 5.119757887904672 MW
# Iteration #510, Total Power Output = 5.198089657572693 MW
# Iteration #516, Total Power Output = 5.221792991051952 MW
# Iteration #522, Total Power Output = 5.2944002241101185 MW
# Iteration #528, Total Power Output = 5.489438623136104 MW
# Iteration #534, Total Power Output = 5.498108786977404 MW
# Iteration #540, Total Power Output = 5.501529842848098 MW
# Iteration #546, Total Power Output = 3.0044219313473923 MW
# Iteration #552, Total Power Output = 5.503146223566201 MW
# Iteration #558, Total Power Output = 5.503220229349161 MW
# Iteration #564, Total Power Output = 5.475079431063661 MW
# Iteration #570, Total Power Output = 5.503232176448792 MW
# Iteration #576, Total Power Output = 5.503244668960217 MW
# Iteration #582, Total Power Output = 5.50324518936856 MW
# Iteration #588, Total Power Output = 5.503245244708222 MW
# Iteration #594, Total Power Output = 5.503245245508932 MW
# Iteration #600, Total Power Output = 5.503245245538332 MW
# Iteration #606, Total Power Output = 5.024513573465013 MW
# Iteration #612, Total Power Output = 5.428925892832429 MW
# Iteration #618, Total Power Output = 2.0607748579741614 MW
# Iteration #624, Total Power Output = 5.496128488894552 MW
# Iteration #630, Total Power Output = 5.496308319564482 MW
# Iteration #636, Total Power Output = 5.499947486369574 MW
# Iteration #642, Total Power Output = 5.497047980291723 MW
# Iteration #648, Total Power Output = 5.503047756841567 MW
# Iteration #654, Total Power Output = 5.503177475440894 MW
# Iteration #660, Total Power Output = 5.5032423576006515 MW
# Iteration #666, Total Power Output = 5.5031850797058715 MW
# Iteration #672, Total Power Output = 5.503242471115725 MW
# Iteration #678, Total Power Output = 5.503245205942683 MW
# Iteration #684, Total Power Output = 5.503245245537724 MW
# Iteration #690, Total Power Output = 4.783613080913913 MW

# %% [markdown]
# ## Wake vs Flow Direction

# %%
# reload optimisation_manager if edited
imp.reload(optimisation_manager)

# initialise floris objec tand file name
direction_floris = Floris('{}.json'.format(case))
direction_name = '{}_direction'.format(case)

turbines = [turbine for _, turbine in direction_floris.farm.flow_field.turbine_map.items()]
num_turbines = len(turbines)
angles = []
power = []

for d in range(-85, 85, 10):
    #direction_floris.farm.flow_field.wind_direction = np.float(d)
    optimisation_manager.set_turbine_attr_vec(np.repeat(range(num_turbines), 1), np.repeat(turbines, 1), \
                     np.repeat(range(1), num_turbines, axis=0), np.repeat(['yaw_angle'], num_turbines, axis=0), \
                     np.ones(num_turbines) * np.radians(d), num_turbines)
    direction_floris.farm.flow_field.calculate_wake()
    flow_field_viz = direction_floris.farm.flow_field
    visualization_manager = VisualizationManager(flow_field_viz, direction_name, plot_wakes=True)
    power.append(optimisation_manager.calc_power(direction_floris)[1] / 10**6)
    angles.append(270.0 + d)
    print('Power Output at {} degree Flow Direction = {} MW'.format(angles[-1], power[-1]))
    visualization_manager.plot_z_planes([0.5])
    
fig, ax = plt.subplots()
ax.plot(angles, power)
ax.set_xlabel('Flow Direction (degrees)')
ax.set_ylabel('Power Output (MW)')
# Out:
# ../imperial_floris/wake_velocity.py:226: RuntimeWarning: invalid value encountered in sqrt
#   velDef = (U_local*(1-np.sqrt(1-((Ct*np.cos(yaw))/(8.0*sigma_y*sigma_z/D**2)) ) )*totGauss)
# Power Output at 185.0 degree Flow Direction = 0.07014308137026438 MW
# Power Output at 195.0 degree Flow Direction = 0.5428267719617309 MW
# Power Output at 205.0 degree Flow Direction = 1.3646176616616177 MW
# Power Output at 215.0 degree Flow Direction = 2.4230879423395506 MW
# Power Output at 225.0 degree Flow Direction = 3.587832816424236 MW
# Power Output at 235.0 degree Flow Direction = 4.670751685672154 MW
# Power Output at 245.0 degree Flow Direction = 5.268126327796782 MW
# Power Output at 255.0 degree Flow Direction = 5.013262796277975 MW
# Power Output at 265.0 degree Flow Direction = 4.498591244341967 MW
# Power Output at 275.0 degree Flow Direction = 4.498591244341968 MW
# Power Output at 285.0 degree Flow Direction = 5.01326279627798 MW
# Power Output at 295.0 degree Flow Direction = 5.268126327796785 MW
# Power Output at 305.0 degree Flow Direction = 4.670751685672155 MW
# Power Output at 315.0 degree Flow Direction = 3.587832816424235 MW
# Power Output at 325.0 degree Flow Direction = 2.42308794233955 MW
# Power Output at 335.0 degree Flow Direction = 1.3646176616616177 MW
# Power Output at 345.0 degree Flow Direction = 0.5428267719617309 MW
# Text(0,0.5,'Power Output (MW)')

# %% [markdown]
# ## Optimise Yaw Angle for Different Wind Directions

# %%
# reload optimisation_manager if edited
imp.reload(optimisation_manager)

# initialise floris objec tand file name
yaw_direction_name = '{}_yaw_direction'.format(case)

# set bounds for the optimization on the turbine parameters (radians for angles)
minimum_values = [-1]
maximum_values = [1]

angles = [0.0, 90.0, 180.0, 270.0]
power = []

for a in range(len(angles)):
    yaw_direction_floris = Floris('{}.json'.format(case))
    yaw_direction_floris.farm.flow_field.wind_direction = np.radians(angles[a])
    #yaw_direction_floris.farm.flow_field.calculate_wake()
    # compute the optimal yaw angles
    yaw_direction_opt_params, yaw_direction_opt_power, yaw_direction_data = optimisation_manager.optimise_func(yaw_direction_floris, yaw_variables, minimum_values, maximum_values, yaw_direction_name, case, global_search=True)

    flow_field_viz = yaw_direction_floris.farm.flow_field
    visualization_manager = VisualizationManager(flow_field_viz, yaw_direction_name, plot_wakes=True)
    power_output = optimisation_manager.calc_power(yaw_direction_floris)
    power.append(power_output[1])
    
fig, ax = plt.subplots()
ax.plot(270.0 - np.asarray(angles), power)
ax.set_xlabel('Flow Direction (degrees)')
ax.set_ylabel('Power Output (MW)')
ax.set_xticks(angles)
# Out:
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5102218.332510335
#             Iterations: 1
#             Function evaluations: 6
#             Gradient evaluations: 1
# basinhopping step 0: f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5196605.782657294
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -5.19661e+06 trial_f -5.19661e+06 accepted 1  lowest_f -5.19661e+06
# found new global minimum on step 1 with function value -5.19661e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4850018.8749880325
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -5.19661e+06 trial_f -4.85002e+06 accepted 0  lowest_f -5.19661e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4835336.805523237
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -5.19661e+06 trial_f -4.83534e+06 accepted 0  lowest_f -5.19661e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4993411.763315381
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -5.19661e+06 trial_f -4.99341e+06 accepted 0  lowest_f -5.19661e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5273008.116861667
#             Iterations: 8
#             Function evaluations: 27
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -5.27301e+06 trial_f -5.27301e+06 accepted 1  lowest_f -5.27301e+06
# found new global minimum on step 5 with function value -5.27301e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4820066.750978663
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -5.27301e+06 trial_f -4.82007e+06 accepted 0  lowest_f -5.27301e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4913975.78549694
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -5.27301e+06 trial_f -4.91398e+06 accepted 0  lowest_f -5.27301e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5322992.512403913
#             Iterations: 14
#             Function evaluations: 95
#             Gradient evaluations: 13
# basinhopping step 8: f -5.32299e+06 trial_f -5.32299e+06 accepted 1  lowest_f -5.32299e+06
# found new global minimum on step 8 with function value -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5126256.267334594
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -5.32299e+06 trial_f -5.12626e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4383257.552312791
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -5.32299e+06 trial_f -4.38326e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4462147.708843803
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -5.32299e+06 trial_f -4.46215e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4922623.769034631
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -5.32299e+06 trial_f -4.92262e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4864664.634709145
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -5.32299e+06 trial_f -4.86466e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5163910.155865255
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -5.32299e+06 trial_f -5.16391e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4838381.430461406
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -5.32299e+06 trial_f -4.83838e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5001000.056566067
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -5.32299e+06 trial_f -5.001e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5124888.285036242
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -5.32299e+06 trial_f -5.12489e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5021815.077484404
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -5.32299e+06 trial_f -5.02182e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5306263.231032662
#             Iterations: 10
#             Function evaluations: 43
#             Gradient evaluations: 6
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -5.32299e+06 trial_f -5.30626e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5238380.360212998
#             Iterations: 8
#             Function evaluations: 28
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -5.32299e+06 trial_f -5.23838e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4743028.988869715
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -5.32299e+06 trial_f -4.74303e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4943371.92028985
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -5.32299e+06 trial_f -4.94337e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5032077.952529947
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -5.32299e+06 trial_f -5.03208e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4901202.3537147865
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -5.32299e+06 trial_f -4.9012e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4406045.089119
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -5.32299e+06 trial_f -4.40605e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4996193.774335039
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -5.32299e+06 trial_f -4.99619e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4937676.61029981
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -5.32299e+06 trial_f -4.93768e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4581541.627697557
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -5.32299e+06 trial_f -4.58154e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4959099.972418049
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 29: f -5.32299e+06 trial_f -4.9591e+06 accepted 0  lowest_f -5.32299e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5322992.51240392
#             Iterations: 13
#             Function evaluations: 88
#             Gradient evaluations: 12
# basinhopping step 30: f -5.32299e+06 trial_f -5.32299e+06 accepted 1  lowest_f -5.32299e+06
# found new global minimum on step 30 with function value -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5161210.242618666
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 31: f -5.32299e+06 trial_f -5.16121e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4992450.040332702
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 32: f -5.32299e+06 trial_f -4.99245e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5209233.528832834
#             Iterations: 9
#             Function evaluations: 34
#             Gradient evaluations: 5
# warning: basinhopping: local minimization failure
# basinhopping step 33: f -5.32299e+06 trial_f -5.20923e+06 accepted 0  lowest_f -5.32299e+06
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5322992.512403917
#             Iterations: 15
#             Function evaluations: 102
#             Gradient evaluations: 14
# basinhopping step 34: f -5.32299e+06 trial_f -5.32299e+06 accepted 1  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4767483.198691993
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 35: f -5.32299e+06 trial_f -4.76748e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4925645.192616834
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 36: f -5.32299e+06 trial_f -4.92565e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4416095.34175597
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 37: f -5.32299e+06 trial_f -4.4161e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5218829.073371955
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 38: f -5.32299e+06 trial_f -5.21883e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5250025.565868144
#             Iterations: 8
#             Function evaluations: 28
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 39: f -5.32299e+06 trial_f -5.25003e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5281500.910326768
#             Iterations: 10
#             Function evaluations: 41
#             Gradient evaluations: 6
# warning: basinhopping: local minimization failure
# basinhopping step 40: f -5.32299e+06 trial_f -5.2815e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5064200.412991601
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 41: f -5.32299e+06 trial_f -5.0642e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4618714.927805355
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 42: f -5.32299e+06 trial_f -4.61871e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5044998.191803135
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 43: f -5.32299e+06 trial_f -5.045e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5084267.397099202
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 44: f -5.32299e+06 trial_f -5.08427e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5046008.358688865
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 45: f -5.32299e+06 trial_f -5.04601e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5125555.539726846
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 46: f -5.32299e+06 trial_f -5.12556e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4970866.717573362
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 47: f -5.32299e+06 trial_f -4.97087e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5025478.512501689
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 48: f -5.32299e+06 trial_f -5.02548e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4730779.474295817
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 49: f -5.32299e+06 trial_f -4.73078e+06 accepted 0  lowest_f -5.32299e+06
# adaptive stepsize: acceptance rate 0.100000 target 0.500000 new stepsize 0.45 old stepsize 0.5
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4409960.658896445
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 50: f -5.32299e+06 trial_f -4.40996e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5032383.969155705
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 51: f -5.32299e+06 trial_f -5.03238e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5200247.02637683
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 52: f -5.32299e+06 trial_f -5.20025e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5225089.43210454
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 53: f -5.32299e+06 trial_f -5.22509e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4957390.367369302
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 54: f -5.32299e+06 trial_f -4.95739e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4992666.401549369
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 55: f -5.32299e+06 trial_f -4.99267e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5032065.873176202
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 56: f -5.32299e+06 trial_f -5.03207e+06 accepted 0  lowest_f -5.32299e+06
# Optimised  Parameters:
# Turbine (200.0, 200.0) parameter yaw_angle = 0.5477972571158399
# Turbine (200.0, 800.0) parameter yaw_angle = -0.5477972089782829
# Turbine (800.0, 200.0) parameter yaw_angle = -9.468950914826441e-09
# Turbine (800.0, 800.0) parameter yaw_angle = -3.3623895499232167e-08
# Turbine (200.0, 200.0) Power Output = 1455829.4698214424 MW
# Turbine (200.0, 800.0) Power Output = 1188169.7354732591 MW
# Turbine (800.0, 200.0) Power Output = 1134162.4165757294 MW
# Turbine (800.0, 800.0) Power Output = 1253904.2662846835 MW
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 5.32299251240392 MW
# Power increased by 4.327023375045617%
# Time to optimise wake = 9.42846393585205 s
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4698820.7648317255
#             Iterations: 6
#             Function evaluations: 12
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 0: f -4.69882e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5725389.407587529
#             Iterations: 8
#             Function evaluations: 28
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -5.72539e+06 trial_f -5.72539e+06 accepted 1  lowest_f -5.72539e+06
# found new global minimum on step 1 with function value -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5203107.038930515
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -5.72539e+06 trial_f -5.20311e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5262818.600881236
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -5.72539e+06 trial_f -5.26282e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4934591.138422317
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -5.72539e+06 trial_f -4.93459e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5331489.139516313
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -5.72539e+06 trial_f -5.33149e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4836948.439874381
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -5.72539e+06 trial_f -4.83695e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5650410.519550144
#             Iterations: 6
#             Function evaluations: 14
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -5.72539e+06 trial_f -5.65041e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4662020.908915383
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -5.72539e+06 trial_f -4.66202e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4901446.896080629
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -5.72539e+06 trial_f -4.90145e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4718365.825230085
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -5.72539e+06 trial_f -4.71837e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4950974.206251474
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -5.72539e+06 trial_f -4.95097e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5114326.952040264
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -5.72539e+06 trial_f -5.11433e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5360758.961501786
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -5.72539e+06 trial_f -5.36076e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4779479.288483254
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -5.72539e+06 trial_f -4.77948e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5428521.581211455
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -5.72539e+06 trial_f -5.42852e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5427265.09674182
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -5.72539e+06 trial_f -5.42727e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4529430.876165595
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -5.72539e+06 trial_f -4.52943e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5008831.938402252
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -5.72539e+06 trial_f -5.00883e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5714032.610170586
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -5.72539e+06 trial_f -5.71403e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4797772.124663683
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -5.72539e+06 trial_f -4.79777e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5292545.855290278
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -5.72539e+06 trial_f -5.29255e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4769997.740156772
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -5.72539e+06 trial_f -4.77e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5700296.983636577
#             Iterations: 7
#             Function evaluations: 22
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -5.72539e+06 trial_f -5.7003e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4608285.286490273
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -5.72539e+06 trial_f -4.60829e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5609000.091345476
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -5.72539e+06 trial_f -5.609e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4380144.125585498
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -5.72539e+06 trial_f -4.38014e+06 accepted 0  lowest_f -5.72539e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4691203.826744251
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -5.72539e+06 trial_f -4.6912e+06 accepted 0  lowest_f -5.72539e+06
# Optimised  Parameters:
# Turbine (200.0, 200.0) parameter yaw_angle = -0.18425730425817669
# Turbine (200.0, 800.0) parameter yaw_angle = 0.5552661780749457
# Turbine (800.0, 200.0) parameter yaw_angle = 0.002111416195823418
# Turbine (800.0, 800.0) parameter yaw_angle = 0.4696299320419659
# Turbine (200.0, 200.0) Power Output = 499549.81471925037 MW
# Turbine (200.0, 800.0) Power Output = 1699029.76022346 MW
# Turbine (800.0, 200.0) Power Output = 867110.2551404388 MW
# Turbine (800.0, 800.0) Power Output = 1625514.029314394 MW
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 5.725389407587529 MW
# Power increased by 12.213728117169543%
# Time to optimise wake = 4.24543309211731 s
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5102218.332510335
#             Iterations: 1
#             Function evaluations: 6
#             Gradient evaluations: 1
# basinhopping step 0: f -5.10222e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5067403.569617199
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -5.10222e+06 trial_f -5.0674e+06 accepted 0  lowest_f -5.10222e+06
# ../imperial_floris/wake_velocity.py:226: RuntimeWarning: invalid value encountered in sqrt
#   velDef = (U_local*(1-np.sqrt(1-((Ct*np.cos(yaw))/(8.0*sigma_y*sigma_z/D**2)) ) )*totGauss)
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5322992.512403887
#             Iterations: 21
#             Function evaluations: 134
#             Gradient evaluations: 18
# basinhopping step 2: f -5.32299e+06 trial_f -5.32299e+06 accepted 1  lowest_f -5.32299e+06
# found new global minimum on step 2 with function value -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5134828.13178916
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -5.32299e+06 trial_f -5.13483e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5186838.250868484
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -5.32299e+06 trial_f -5.18684e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5246728.6733999215
#             Iterations: 7
#             Function evaluations: 21
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -5.32299e+06 trial_f -5.24673e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4528593.872588062
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -5.32299e+06 trial_f -4.52859e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4607961.491095073
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -5.32299e+06 trial_f -4.60796e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5266241.795506619
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -5.32299e+06 trial_f -5.26624e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4955868.79692336
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -5.32299e+06 trial_f -4.95587e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4800906.625747634
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -5.32299e+06 trial_f -4.80091e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5300897.788245667
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -5.32299e+06 trial_f -5.3009e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5225553.457287406
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -5.32299e+06 trial_f -5.22555e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4803576.007328876
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -5.32299e+06 trial_f -4.80358e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4969892.755783189
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -5.32299e+06 trial_f -4.96989e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4944185.549431952
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -5.32299e+06 trial_f -4.94419e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4962660.890865447
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -5.32299e+06 trial_f -4.96266e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4890168.4023208795
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -5.32299e+06 trial_f -4.89017e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5186424.393493822
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -5.32299e+06 trial_f -5.18642e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5166203.991188709
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -5.32299e+06 trial_f -5.1662e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4855555.953739766
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -5.32299e+06 trial_f -4.85556e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5043807.953200247
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -5.32299e+06 trial_f -5.04381e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5021805.738344447
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -5.32299e+06 trial_f -5.02181e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4805736.265475882
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -5.32299e+06 trial_f -4.80574e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4618645.235569416
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -5.32299e+06 trial_f -4.61865e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5248804.153978085
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -5.32299e+06 trial_f -5.2488e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5200470.997818324
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -5.32299e+06 trial_f -5.20047e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5303681.317079264
#             Iterations: 8
#             Function evaluations: 27
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 27: f -5.32299e+06 trial_f -5.30368e+06 accepted 0  lowest_f -5.32299e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5024919.876366093
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 28: f -5.32299e+06 trial_f -5.02492e+06 accepted 0  lowest_f -5.32299e+06
# Optimised  Parameters:
# Turbine (200.0, 200.0) parameter yaw_angle = 6.02333819745575e-09
# Turbine (200.0, 800.0) parameter yaw_angle = -5.178206576318953e-08
# Turbine (800.0, 200.0) parameter yaw_angle = 0.5477972751868425
# Turbine (800.0, 800.0) parameter yaw_angle = 0.547797381490883
# Turbine (200.0, 200.0) Power Output = 1179724.566143643 MW
# Turbine (200.0, 800.0) Power Output = 1160976.7920588176 MW
# Turbine (800.0, 200.0) Power Output = 1313328.3846591031 MW
# Turbine (800.0, 800.0) Power Output = 1370890.1344818952 MW
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 5.322992512403887 MW
# Power increased by 4.32702337504496%
# Time to optimise wake = 4.593898057937622 s
# =====================================================================
# Optimizing...
# Number of parameters to optimize =  4
# =====================================================================
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -5798199.549733526
#             Iterations: 14
#             Function evaluations: 93
#             Gradient evaluations: 13
# basinhopping step 0: f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5518941.36341076
#             Iterations: 6
#             Function evaluations: 14
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 1: f -5.7982e+06 trial_f -5.51894e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4889558.719137305
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 2: f -5.7982e+06 trial_f -4.88956e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5757276.510735581
#             Iterations: 7
#             Function evaluations: 20
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 3: f -5.7982e+06 trial_f -5.75728e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4964769.030093228
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 4: f -5.7982e+06 trial_f -4.96477e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5021343.209701236
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 5: f -5.7982e+06 trial_f -5.02134e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5251870.924230475
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 6: f -5.7982e+06 trial_f -5.25187e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4501291.116795543
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 7: f -5.7982e+06 trial_f -4.50129e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4549857.070609279
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 8: f -5.7982e+06 trial_f -4.54986e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5130409.464195592
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 9: f -5.7982e+06 trial_f -5.13041e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5790016.472442478
#             Iterations: 8
#             Function evaluations: 29
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 10: f -5.7982e+06 trial_f -5.79002e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5536190.9800678175
#             Iterations: 6
#             Function evaluations: 14
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 11: f -5.7982e+06 trial_f -5.53619e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4778454.904831605
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 12: f -5.7982e+06 trial_f -4.77845e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5182593.388273226
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 13: f -5.7982e+06 trial_f -5.18259e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5438044.566499975
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 14: f -5.7982e+06 trial_f -5.43804e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5398263.369920926
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 15: f -5.7982e+06 trial_f -5.39826e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5016239.766737084
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 16: f -5.7982e+06 trial_f -5.01624e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4796373.878062774
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 17: f -5.7982e+06 trial_f -4.79637e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5066955.417260364
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 18: f -5.7982e+06 trial_f -5.06696e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5598426.188839571
#             Iterations: 8
#             Function evaluations: 28
#             Gradient evaluations: 4
# warning: basinhopping: local minimization failure
# basinhopping step 19: f -5.7982e+06 trial_f -5.59843e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4566353.461584008
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 20: f -5.7982e+06 trial_f -4.56635e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5351820.184431899
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 21: f -5.7982e+06 trial_f -5.35182e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5631555.251866169
#             Iterations: 6
#             Function evaluations: 14
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 22: f -5.7982e+06 trial_f -5.63156e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5702770.490863227
#             Iterations: 7
#             Function evaluations: 22
#             Gradient evaluations: 3
# warning: basinhopping: local minimization failure
# basinhopping step 23: f -5.7982e+06 trial_f -5.70277e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4629526.948847988
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 24: f -5.7982e+06 trial_f -4.62953e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -5739179.8086818345
#             Iterations: 6
#             Function evaluations: 13
#             Gradient evaluations: 2
# warning: basinhopping: local minimization failure
# basinhopping step 25: f -5.7982e+06 trial_f -5.73918e+06 accepted 0  lowest_f -5.7982e+06
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4643876.863987665
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# warning: basinhopping: local minimization failure
# basinhopping step 26: f -5.7982e+06 trial_f -4.64388e+06 accepted 0  lowest_f -5.7982e+06
# Optimised  Parameters:
# Turbine (200.0, 200.0) parameter yaw_angle = 0.5084616695156968
# Turbine (200.0, 800.0) parameter yaw_angle = 2.872259380865399e-07
# Turbine (800.0, 200.0) parameter yaw_angle = 0.5084616702183946
# Turbine (800.0, 800.0) parameter yaw_angle = -8.023766278548032e-08
# Turbine (200.0, 200.0) Power Output = 799598.6961300857 MW
# Turbine (200.0, 800.0) Power Output = 1617995.9853452542 MW
# Turbine (800.0, 200.0) Power Output = 1701209.2074832222 MW
# Turbine (800.0, 800.0) Power Output = 525072.9779422473 MW
# Initial Power Output = 5.102218332510335 MW
# Optimised, Power Output = 5.798199549733526 MW
# Power increased by 13.640757252360894%
# Time to optimise wake = 7.2178239822387695 s
# [<matplotlib.axis.XTick at 0x111447be0>,
#  <matplotlib.axis.XTick at 0x1112921d0>,
#  <matplotlib.axis.XTick at 0x111292390>,
#  <matplotlib.axis.XTick at 0x1110c21d0>]
